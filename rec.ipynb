# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import faiss
import requests

# %%
df =pd.read_csv("data.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# create the textual representation for the LLM

# %%
def create_textual_rep(row):
    text_rep=f"""
    Type:{row['type']},
    Title:{row['title']},
    Director:{row['director']},
    Description:{row['description']},
    Genres:{row['listed_in']},
    Released:{row['release_year']}
    """
    return text_rep

# %%
df['text_rep']=df.apply(create_textual_rep,axis=1)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
#
#                                             text_rep
# 0  \n    Type:Movie,\n    Title:Dick Johnson Is D...
# 1  \n    Type:TV Show,\n    Title:Blood & Water,\...
# 2  \n    Type:TV Show,\n    Title:Ganglands,\n   ...
# 3  \n    Type:TV Show,\n    Title:Jailbirds New O...
# 4  \n    Type:TV Show,\n    Title:Kota Factory,\n...

# %%
dim = 4096
index = faiss.IndexFlatL2(dim)
X=np.zeros((len(df['text_rep']),dim),dtype='float32')

# %%
print(df['text_rep'])
# Out:
# 0       \n    Type:Movie,\n    Title:Dick Johnson Is D...
# 1       \n    Type:TV Show,\n    Title:Blood & Water,\...
# 2       \n    Type:TV Show,\n    Title:Ganglands,\n   ...
# 3       \n    Type:TV Show,\n    Title:Jailbirds New O...
# 4       \n    Type:TV Show,\n    Title:Kota Factory,\n...
#                               ...
# 8802    \n    Type:Movie,\n    Title:Zodiac,\n    Dire...
# 8803    \n    Type:TV Show,\n    Title:Zombie Dumb,\n ...
# 8804    \n    Type:Movie,\n    Title:Zombieland,\n    ...
# 8805    \n    Type:Movie,\n    Title:Zoom,\n    Direct...
# 8806    \n    Type:Movie,\n    Title:Zubaan,\n    Dire...
# Name: text_rep, Length: 8807, dtype: object

# %%
# for i, representation in enumerate(df['text_rep']):
#     if i % 20 == 0:
#         print('Processed',str(i),'instances')
#     res = requests.post('http://localhost:11434/api/embeddings',
#         json={
#             'model':'llama2',
#             'prompt': representation
#         }
#     )
#     embedding = res.json()['embedding']
#     X[i]=np.array(embedding)
# index.add(X)

# %%
import asyncio
import aiohttp
import nest_asyncio
import numpy as np
from tqdm.notebook import tqdm  # for nice Jupyter progress bars

# Patch the event loop for Jupyter
nest_asyncio.apply()

# Parameters
url = 'http://localhost:11434/api/embeddings'
model = 'llama2'
concurrency_limit = 100  # Tweak based on your system
expected_dim = dim      # Change based on your model output size
X = np.zeros((len(df), expected_dim), dtype=np.float32)

sem = asyncio.Semaphore(concurrency_limit)

async def fetch_embedding(session, i, prompt):
    async with sem:
        for _ in range(3):  # Retry logic
            try:
                async with session.post(url, json={'model': model, 'prompt': prompt}, timeout=10) as resp:
                    if resp.status == 200:
                        data = await resp.json()
                        embedding = data.get('embedding')
                        if embedding:
                            return i, np.array(embedding, dtype=np.float32)
            except Exception:
                await asyncio.sleep(0.5)  # Backoff
    print(f"❌ Failed to get embedding for index {i}")
    return i, None

async def process_all():
    tasks = []
    async with aiohttp.ClientSession() as session:
        for i, prompt in enumerate(df['text_rep']):
            tasks.append(fetch_embedding(session, i, prompt))

        for f in tqdm(asyncio.as_completed(tasks), total=len(tasks)):
            i, emb = await f
            if emb is not None:
                X[i] = emb

    print("✅ Done embedding all.")

# Run the async function in the current event loop
await process_all()
# Out:
#   0%|          | 0/8807 [00:00<?, ?it/s]
# ❌ Failed to get embedding for index 253
# ❌ Failed to get embedding for index 4310
# ❌ Failed to get embedding for index 249
# ❌ Failed to get embedding for index 5829
# ❌ Failed to get embedding for index 7545
# ❌ Failed to get embedding for index 245
# ❌ Failed to get embedding for index 2098
# ❌ Failed to get embedding for index 679
# ❌ Failed to get embedding for index 4403
# ❌ Failed to get embedding for index 4396
# ❌ Failed to get embedding for index 5837
# ❌ Failed to get embedding for index 7496
# ❌ Failed to get embedding for index 4399
# ❌ Failed to get embedding for index 5816
# ❌ Failed to get embedding for index 4391
# ❌ Failed to get embedding for index 609
# ❌ Failed to get embedding for index 719
# ❌ Failed to get embedding for index 7589
# ❌ Failed to get embedding for index 705
# ❌ Failed to get embedding for index 5841
# ❌ Failed to get embedding for index 2060
# ❌ Failed to get embedding for index 7558
# ❌ Failed to get embedding for index 702
# ❌ Failed to get embedding for index 2146
# ❌ Failed to get embedding for index 215
# ❌ Failed to get embedding for index 631
# ❌ Failed to get embedding for index 712
# ❌ Failed to get embedding for index 5851
# ❌ Failed to get embedding for index 4377
# ❌ Failed to get embedding for index 4392
# ❌ Failed to get embedding for index 4387
# ❌ Failed to get embedding for index 674
# ❌ Failed to get embedding for index 7475
# ❌ Failed to get embedding for index 231
# ❌ Failed to get embedding for index 219
# ❌ Failed to get embedding for index 2085
# ❌ Failed to get embedding for index 5856
# ❌ Failed to get embedding for index 682
# ❌ Failed to get embedding for index 7467
# ❌ Failed to get embedding for index 5857
# ❌ Failed to get embedding for index 7488
# ❌ Failed to get embedding for index 216
# ❌ Failed to get embedding for index 4445
# ❌ Failed to get embedding for index 150
# ❌ Failed to get embedding for index 5859
# ❌ Failed to get embedding for index 2026
# ❌ Failed to get embedding for index 226
# ❌ Failed to get embedding for index 5860
# ❌ Failed to get embedding for index 670
# ❌ Failed to get embedding for index 7497
# ❌ Failed to get embedding for index 7468
# ❌ Failed to get embedding for index 2069
# ❌ Failed to get embedding for index 5864
# ❌ Failed to get embedding for index 211
# ❌ Failed to get embedding for index 210
# ❌ Failed to get embedding for index 4362
# ❌ Failed to get embedding for index 7518
# ❌ Failed to get embedding for index 2065
# ❌ Failed to get embedding for index 5865
# ❌ Failed to get embedding for index 5866
# ❌ Failed to get embedding for index 5867
# ❌ Failed to get embedding for index 223
# ❌ Failed to get embedding for index 668
# ❌ Failed to get embedding for index 699
# ❌ Failed to get embedding for index 608
# ❌ Failed to get embedding for index 7559
# ❌ Failed to get embedding for index 5870
# ❌ Failed to get embedding for index 7501
# ❌ Failed to get embedding for index 220
# ❌ Failed to get embedding for index 7517
# ❌ Failed to get embedding for index 5874
# ❌ Failed to get embedding for index 7580
# ❌ Failed to get embedding for index 603
# ❌ Failed to get embedding for index 217
# ❌ Failed to get embedding for index 2125
# ❌ Failed to get embedding for index 673
# ❌ Failed to get embedding for index 7509
# ❌ Failed to get embedding for index 200
# ❌ Failed to get embedding for index 5877
# ❌ Failed to get embedding for index 207
# ❌ Failed to get embedding for index 7560
# ❌ Failed to get embedding for index 7477
# ❌ Failed to get embedding for index 4337
# ❌ Failed to get embedding for index 7498
# ❌ Failed to get embedding for index 5899
# ❌ Failed to get embedding for index 4374
# ❌ Failed to get embedding for index 2136
# ❌ Failed to get embedding for index 198
# ❌ Failed to get embedding for index 4364
# ❌ Failed to get embedding for index 7529
# ❌ Failed to get embedding for index 7528
# ❌ Failed to get embedding for index 4366
# ❌ Failed to get embedding for index 5910
# ❌ Failed to get embedding for index 203
# ❌ Failed to get embedding for index 7557
# ❌ Failed to get embedding for index 704
# ❌ Failed to get embedding for index 5908
# ❌ Failed to get embedding for index 653
# ❌ Failed to get embedding for index 4357
# ❌ Failed to get embedding for index 595
# ❌ Failed to get embedding for index 173
# ❌ Failed to get embedding for index 2131
# ❌ Failed to get embedding for index 4340
# ❌ Failed to get embedding for index 192
# ❌ Failed to get embedding for index 639
# ❌ Failed to get embedding for index 4359
# ❌ Failed to get embedding for index 7596
# ❌ Failed to get embedding for index 654
# ❌ Failed to get embedding for index 193
# ❌ Failed to get embedding for index 5898
# ❌ Failed to get embedding for index 599
# ❌ Failed to get embedding for index 2134
# ❌ Failed to get embedding for index 693
# ❌ Failed to get embedding for index 5900
# ❌ Failed to get embedding for index 4356
# ❌ Failed to get embedding for index 191
# ❌ Failed to get embedding for index 718
# ❌ Failed to get embedding for index 7562
# ❌ Failed to get embedding for index 2122
# ❌ Failed to get embedding for index 627
# ❌ Failed to get embedding for index 171
# ❌ Failed to get embedding for index 148
# ❌ Failed to get embedding for index 2129
# ❌ Failed to get embedding for index 4338
# ❌ Failed to get embedding for index 7574
# ❌ Failed to get embedding for index 644
# ❌ Failed to get embedding for index 179
# ❌ Failed to get embedding for index 5879
# ❌ Failed to get embedding for index 5903
# ❌ Failed to get embedding for index 2055
# ❌ Failed to get embedding for index 657
# ❌ Failed to get embedding for index 5906
# ❌ Failed to get embedding for index 2117
# ❌ Failed to get embedding for index 176
# ❌ Failed to get embedding for index 4438
# ❌ Failed to get embedding for index 175
# ❌ Failed to get embedding for index 5881
# ❌ Failed to get embedding for index 641
# ❌ Failed to get embedding for index 7470
# ❌ Failed to get embedding for index 2035
# ❌ Failed to get embedding for index 5882
# ❌ Failed to get embedding for index 4434
# ❌ Failed to get embedding for index 7550
# ❌ Failed to get embedding for index 2116
# ❌ Failed to get embedding for index 4433
# ❌ Failed to get embedding for index 2115
# ❌ Failed to get embedding for index 7539
# ❌ Failed to get embedding for index 596
# ❌ Failed to get embedding for index 157
# ❌ Failed to get embedding for index 7486
# ❌ Failed to get embedding for index 5889
# ❌ Failed to get embedding for index 2108
# ❌ Failed to get embedding for index 170
# ❌ Failed to get embedding for index 4332
# ❌ Failed to get embedding for index 2107
# ❌ Failed to get embedding for index 7525
# ❌ Failed to get embedding for index 2039
# ❌ Failed to get embedding for index 167
# ❌ Failed to get embedding for index 7491
# ❌ Failed to get embedding for index 708
# ❌ Failed to get embedding for index 636
# ❌ Failed to get embedding for index 2021
# ❌ Failed to get embedding for index 600
# ❌ Failed to get embedding for index 7502
# ❌ Failed to get embedding for index 4432
# ❌ Failed to get embedding for index 4428
# ❌ Failed to get embedding for index 4327
# ❌ Failed to get embedding for index 2030
# ❌ Failed to get embedding for index 2112
# ❌ Failed to get embedding for index 635
# ❌ Failed to get embedding for index 160
# ❌ Failed to get embedding for index 638
# ❌ Failed to get embedding for index 7492
# ❌ Failed to get embedding for index 159
# ❌ Failed to get embedding for index 4429
# ❌ Failed to get embedding for index 7549
# ❌ Failed to get embedding for index 7554
# ❌ Failed to get embedding for index 2101
# ❌ Failed to get embedding for index 587
# ❌ Failed to get embedding for index 4423
# ❌ Failed to get embedding for index 2111
# ❌ Failed to get embedding for index 4318
# ❌ Failed to get embedding for index 278
# ❌ Failed to get embedding for index 4317
# ❌ Failed to get embedding for index 7584
# ❌ Failed to get embedding for index 262
# ❌ Failed to get embedding for index 7512
# ❌ Failed to get embedding for index 715
# ❌ Failed to get embedding for index 2019
# ❌ Failed to get embedding for index 2037
# ❌ Failed to get embedding for index 269
# ❌ Failed to get embedding for index 4313
# ❌ Failed to get embedding for index 4415
# ❌ Failed to get embedding for index 2105
# ❌ Failed to get embedding for index 266
# ❌ Failed to get embedding for index 2102
# ❌ Failed to get embedding for index 711
# ❌ Failed to get embedding for index 1402
# ❌ Failed to get embedding for index 1320
# ❌ Failed to get embedding for index 1386
# ❌ Failed to get embedding for index 1394
# ❌ Failed to get embedding for index 1316
# ❌ Failed to get embedding for index 1318
# ❌ Failed to get embedding for index 1379
# ❌ Failed to get embedding for index 1301
# ❌ Failed to get embedding for index 1356
# ❌ Failed to get embedding for index 1368
# ❌ Failed to get embedding for index 1326
# ❌ Failed to get embedding for index 1365
# ❌ Failed to get embedding for index 1384
# ❌ Failed to get embedding for index 1374
# ❌ Failed to get embedding for index 1411
# ❌ Failed to get embedding for index 1331
# ❌ Failed to get embedding for index 1391
# ❌ Failed to get embedding for index 1337
# ❌ Failed to get embedding for index 1328
# ❌ Failed to get embedding for index 1360
# ❌ Failed to get embedding for index 1353
# ❌ Failed to get embedding for index 1332
# ❌ Failed to get embedding for index 1339
# ❌ Failed to get embedding for index 1347
# ❌ Failed to get embedding for index 1310
# ❌ Failed to get embedding for index 1417
# ❌ Failed to get embedding for index 1432
# ❌ Failed to get embedding for index 1427
# ❌ Failed to get embedding for index 1419
# ❌ Failed to get embedding for index 1390
# ❌ Failed to get embedding for index 1436
# ❌ Failed to get embedding for index 1423
# ❌ Failed to get embedding for index 1435
# ❌ Failed to get embedding for index 819
# ❌ Failed to get embedding for index 7026
# ❌ Failed to get embedding for index 823
# ❌ Failed to get embedding for index 6891
# ❌ Failed to get embedding for index 825
# ❌ Failed to get embedding for index 8190
# ❌ Failed to get embedding for index 6964
# ❌ Failed to get embedding for index 821
# ❌ Failed to get embedding for index 722
# ❌ Failed to get embedding for index 810
# ❌ Failed to get embedding for index 822
# ❌ Failed to get embedding for index 815
# ❌ Failed to get embedding for index 6933
# ❌ Failed to get embedding for index 8199
# ❌ Failed to get embedding for index 8200
# ❌ Failed to get embedding for index 8202
# ❌ Failed to get embedding for index 739
# ❌ Failed to get embedding for index 8203
# ❌ Failed to get embedding for index 802
# ❌ Failed to get embedding for index 7014
# ❌ Failed to get embedding for index 6972
# ❌ Failed to get embedding for index 7018
# ❌ Failed to get embedding for index 8214
# ❌ Failed to get embedding for index 6956
# ❌ Failed to get embedding for index 814
# ❌ Failed to get embedding for index 801
# ❌ Failed to get embedding for index 6943
# ❌ Failed to get embedding for index 8229
# ❌ Failed to get embedding for index 8233
# ❌ Failed to get embedding for index 8232
# ❌ Failed to get embedding for index 8234
# ❌ Failed to get embedding for index 6889
# ❌ Failed to get embedding for index 8235
# ❌ Failed to get embedding for index 795
# ❌ Failed to get embedding for index 738
# ❌ Failed to get embedding for index 8251
# ❌ Failed to get embedding for index 8250
# ❌ Failed to get embedding for index 7031
# ❌ Failed to get embedding for index 737
# ❌ Failed to get embedding for index 724
# ❌ Failed to get embedding for index 6900
# ❌ Failed to get embedding for index 762
# ❌ Failed to get embedding for index 8261
# ❌ Failed to get embedding for index 778
# ❌ Failed to get embedding for index 8267
# ❌ Failed to get embedding for index 777
# ❌ Failed to get embedding for index 776
# ❌ Failed to get embedding for index 8270
# ❌ Failed to get embedding for index 8273
# ❌ Failed to get embedding for index 742
# ❌ Failed to get embedding for index 8275
# ❌ Failed to get embedding for index 774
# ❌ Failed to get embedding for index 6984
# ❌ Failed to get embedding for index 735
# ❌ Failed to get embedding for index 859
# ❌ Failed to get embedding for index 8280
# ❌ Failed to get embedding for index 8279
# ❌ Failed to get embedding for index 8283
# ❌ Failed to get embedding for index 860
# ❌ Failed to get embedding for index 8282
# ❌ Failed to get embedding for index 8286
# ❌ Failed to get embedding for index 781
# ❌ Failed to get embedding for index 6923
# ❌ Failed to get embedding for index 6951
# ❌ Failed to get embedding for index 836
# ❌ Failed to get embedding for index 8291
# ❌ Failed to get embedding for index 8293
# ❌ Failed to get embedding for index 6926
# ❌ Failed to get embedding for index 8294
# ❌ Failed to get embedding for index 837
# ❌ Failed to get embedding for index 840
# ❌ Failed to get embedding for index 8298
# ❌ Failed to get embedding for index 6970
# ❌ Failed to get embedding for index 848
# ❌ Failed to get embedding for index 8307
# ❌ Failed to get embedding for index 8306
# ❌ Failed to get embedding for index 844
# ❌ Failed to get embedding for index 6992
# ❌ Failed to get embedding for index 6963
# ❌ Failed to get embedding for index 832
# ❌ Failed to get embedding for index 8311
# ❌ Failed to get embedding for index 7011
# ❌ Failed to get embedding for index 833
# ❌ Failed to get embedding for index 6910
# ❌ Failed to get embedding for index 835
# ❌ Failed to get embedding for index 8322
# ❌ Failed to get embedding for index 6976
# ❌ Failed to get embedding for index 754
# ❌ Failed to get embedding for index 8324
# ❌ Failed to get embedding for index 8323
# ❌ Failed to get embedding for index 6916
# ❌ Failed to get embedding for index 733
# ❌ Failed to get embedding for index 6897
# ❌ Failed to get embedding for index 8327
# ❌ Failed to get embedding for index 2816
# ❌ Failed to get embedding for index 2829
# ❌ Failed to get embedding for index 2831
# ❌ Failed to get embedding for index 2734
# ❌ Failed to get embedding for index 2809
# ❌ Failed to get embedding for index 2743
# ❌ Failed to get embedding for index 2805
# ❌ Failed to get embedding for index 2823
# ❌ Failed to get embedding for index 2779
# ❌ Failed to get embedding for index 2802
# ❌ Failed to get embedding for index 2799
# ❌ Failed to get embedding for index 2789
# ❌ Failed to get embedding for index 2796
# ❌ Failed to get embedding for index 2787
# ❌ Failed to get embedding for index 2786
# ❌ Failed to get embedding for index 2788
# ❌ Failed to get embedding for index 2741
# ❌ Failed to get embedding for index 2736
# ❌ Failed to get embedding for index 2773
# ❌ Failed to get embedding for index 2762
# ❌ Failed to get embedding for index 2854
# ❌ Failed to get embedding for index 2868
# ❌ Failed to get embedding for index 2761
# ❌ Failed to get embedding for index 2763
# ❌ Failed to get embedding for index 2855
# ❌ Failed to get embedding for index 2872
# ❌ Failed to get embedding for index 2851
# ❌ Failed to get embedding for index 2849
# ❌ Failed to get embedding for index 2843
# ❌ Failed to get embedding for index 2832
# ❌ Failed to get embedding for index 2819
# ❌ Failed to get embedding for index 2749
# ❌ Failed to get embedding for index 2820
# ❌ Failed to get embedding for index 2834
# ❌ Failed to get embedding for index 2748
# ❌ Failed to get embedding for index 2747
# ❌ Failed to get embedding for index 2750
# ❌ Failed to get embedding for index 4858
# ❌ Failed to get embedding for index 3801
# ❌ Failed to get embedding for index 6018
# ❌ Failed to get embedding for index 3794
# ❌ Failed to get embedding for index 3813
# ❌ Failed to get embedding for index 3771
# ❌ Failed to get embedding for index 7398
# ❌ Failed to get embedding for index 3810
# ❌ Failed to get embedding for index 7418
# ❌ Failed to get embedding for index 3812
# ❌ Failed to get embedding for index 6012
# ❌ Failed to get embedding for index 4846
# ❌ Failed to get embedding for index 7438
# ❌ Failed to get embedding for index 4865
# ❌ Failed to get embedding for index 7395
# ❌ Failed to get embedding for index 5986
# ❌ Failed to get embedding for index 4848
# ❌ Failed to get embedding for index 5947
# ❌ Failed to get embedding for index 6034
# ❌ Failed to get embedding for index 7346
# ❌ Failed to get embedding for index 4856
# ❌ Failed to get embedding for index 4838
# ❌ Failed to get embedding for index 5973
# ❌ Failed to get embedding for index 7444
# ❌ Failed to get embedding for index 3806
# ❌ Failed to get embedding for index 4839
# ❌ Failed to get embedding for index 7324
# ❌ Failed to get embedding for index 5946
# ❌ Failed to get embedding for index 3802
# ❌ Failed to get embedding for index 7394
# ❌ Failed to get embedding for index 5951
# ❌ Failed to get embedding for index 3790
# ❌ Failed to get embedding for index 7403
# ❌ Failed to get embedding for index 5974
# ❌ Failed to get embedding for index 5948
# ❌ Failed to get embedding for index 7406
# ❌ Failed to get embedding for index 3779
# ❌ Failed to get embedding for index 4862
# ❌ Failed to get embedding for index 3777
# ❌ Failed to get embedding for index 4840
# ❌ Failed to get embedding for index 7437
# ❌ Failed to get embedding for index 3776
# ❌ Failed to get embedding for index 3778
# ❌ Failed to get embedding for index 7349
# ❌ Failed to get embedding for index 4833
# ❌ Failed to get embedding for index 3775
# ❌ Failed to get embedding for index 4754
# ❌ Failed to get embedding for index 3770
# ❌ Failed to get embedding for index 4749
# ❌ Failed to get embedding for index 3782
# ❌ Failed to get embedding for index 7454
# ❌ Failed to get embedding for index 7344
# ❌ Failed to get embedding for index 6004
# ❌ Failed to get embedding for index 3786
# ❌ Failed to get embedding for index 7365
# ❌ Failed to get embedding for index 4830
# ❌ Failed to get embedding for index 7456
# ❌ Failed to get embedding for index 5949
# ❌ Failed to get embedding for index 4756
# ❌ Failed to get embedding for index 7461
# ❌ Failed to get embedding for index 7405
# ❌ Failed to get embedding for index 5972
# ❌ Failed to get embedding for index 3757
# ❌ Failed to get embedding for index 3768
# ❌ Failed to get embedding for index 4810
# ❌ Failed to get embedding for index 3751
# ❌ Failed to get embedding for index 7380
# ❌ Failed to get embedding for index 5954
# ❌ Failed to get embedding for index 5957
# ❌ Failed to get embedding for index 4806
# ❌ Failed to get embedding for index 7392
# ❌ Failed to get embedding for index 7413
# ❌ Failed to get embedding for index 4812
# ❌ Failed to get embedding for index 7330
# ❌ Failed to get embedding for index 3754
# ❌ Failed to get embedding for index 5937
# ❌ Failed to get embedding for index 3755
# ❌ Failed to get embedding for index 7412
# ❌ Failed to get embedding for index 7416
# ❌ Failed to get embedding for index 5915
# ❌ Failed to get embedding for index 3829
# ❌ Failed to get embedding for index 5944
# ❌ Failed to get embedding for index 7329
# ❌ Failed to get embedding for index 6019
# ❌ Failed to get embedding for index 6049
# ❌ Failed to get embedding for index 7374
# ❌ Failed to get embedding for index 3821
# ❌ Failed to get embedding for index 3852
# ❌ Failed to get embedding for index 5928
# ❌ Failed to get embedding for index 7431
# ❌ Failed to get embedding for index 4763
# ❌ Failed to get embedding for index 3733
# ❌ Failed to get embedding for index 4798
# ❌ Failed to get embedding for index 7426
# ❌ Failed to get embedding for index 5941
# ❌ Failed to get embedding for index 7369
# ❌ Failed to get embedding for index 4777
# ❌ Failed to get embedding for index 7360
# ❌ Failed to get embedding for index 4796
# ❌ Failed to get embedding for index 4797
# ❌ Failed to get embedding for index 3847
# ❌ Failed to get embedding for index 6017
# ❌ Failed to get embedding for index 5929
# ❌ Failed to get embedding for index 3855
# ❌ Failed to get embedding for index 7443
# ❌ Failed to get embedding for index 5996
# ❌ Failed to get embedding for index 4790
# ❌ Failed to get embedding for index 7464
# ❌ Failed to get embedding for index 5922
# ❌ Failed to get embedding for index 4785
# ❌ Failed to get embedding for index 6001
# ❌ Failed to get embedding for index 4778
# ❌ Failed to get embedding for index 5930
# ❌ Failed to get embedding for index 3736
# ❌ Failed to get embedding for index 3846
# ❌ Failed to get embedding for index 4764
# ❌ Failed to get embedding for index 4874
# ❌ Failed to get embedding for index 3827
# ❌ Failed to get embedding for index 3819
# ❌ Failed to get embedding for index 6046
# ❌ Failed to get embedding for index 7400
# ❌ Failed to get embedding for index 7355
# ❌ Failed to get embedding for index 4783
# ❌ Failed to get embedding for index 4774
# ❌ Failed to get embedding for index 3735
# ❌ Failed to get embedding for index 7328
# ❌ Failed to get embedding for index 6005
# ❌ Failed to get embedding for index 3834
# ❌ Failed to get embedding for index 7450
# ❌ Failed to get embedding for index 3838
# ❌ Failed to get embedding for index 3839
# ❌ Failed to get embedding for index 4771
# ❌ Failed to get embedding for index 5939
# ❌ Failed to get embedding for index 4776
# ❌ Failed to get embedding for index 6006
# ❌ Failed to get embedding for index 7393
# ❌ Failed to get embedding for index 4784
# ❌ Failed to get embedding for index 4779
# ❌ Failed to get embedding for index 5935
# ❌ Failed to get embedding for index 7368
# ❌ Failed to get embedding for index 6050
# ❌ Failed to get embedding for index 4781
# ❌ Failed to get embedding for index 3749
# ❌ Failed to get embedding for index 7388
# ❌ Failed to get embedding for index 4768
# ❌ Failed to get embedding for index 3818
# ❌ Failed to get embedding for index 4782
# ❌ Failed to get embedding for index 5998
# ❌ Failed to get embedding for index 7332
# ❌ Failed to get embedding for index 3828
# ❌ Failed to get embedding for index 4769
# ❌ Failed to get embedding for index 7350
# ❌ Failed to get embedding for index 4881
# ❌ Failed to get embedding for index 7333
# ❌ Failed to get embedding for index 3822
# ❌ Failed to get embedding for index 3840
# ❌ Failed to get embedding for index 4780
# ❌ Failed to get embedding for index 360
# ❌ Failed to get embedding for index 311
# ❌ Failed to get embedding for index 5801
# ❌ Failed to get embedding for index 310
# ❌ Failed to get embedding for index 338
# ❌ Failed to get embedding for index 352
# ❌ Failed to get embedding for index 5752
# ❌ Failed to get embedding for index 359
# ❌ Failed to get embedding for index 5764
# ❌ Failed to get embedding for index 358
# ❌ Failed to get embedding for index 363
# ❌ Failed to get embedding for index 356
# ❌ Failed to get embedding for index 5743
# ❌ Failed to get embedding for index 5749
# ❌ Failed to get embedding for index 362
# ❌ Failed to get embedding for index 364
# ❌ Failed to get embedding for index 361
# ❌ Failed to get embedding for index 5756
# ❌ Failed to get embedding for index 301
# ❌ Failed to get embedding for index 432
# ❌ Failed to get embedding for index 5790
# ❌ Failed to get embedding for index 353
# ❌ Failed to get embedding for index 351
# ❌ Failed to get embedding for index 5747
# ❌ Failed to get embedding for index 355
# ❌ Failed to get embedding for index 349
# ❌ Failed to get embedding for index 419
# ❌ Failed to get embedding for index 430
# ❌ Failed to get embedding for index 431
# ❌ Failed to get embedding for index 345
# ❌ Failed to get embedding for index 357
# ❌ Failed to get embedding for index 344
# ❌ Failed to get embedding for index 414
# ❌ Failed to get embedding for index 339
# ❌ Failed to get embedding for index 5781
# ❌ Failed to get embedding for index 410
# ❌ Failed to get embedding for index 5776
# ❌ Failed to get embedding for index 433
# ❌ Failed to get embedding for index 426
# ❌ Failed to get embedding for index 348
# ❌ Failed to get embedding for index 5773
# ❌ Failed to get embedding for index 409
# ❌ Failed to get embedding for index 308
# ❌ Failed to get embedding for index 5797
# ❌ Failed to get embedding for index 326
# ❌ Failed to get embedding for index 332
# ❌ Failed to get embedding for index 298
# ❌ Failed to get embedding for index 5802
# ❌ Failed to get embedding for index 5760
# ❌ Failed to get embedding for index 320
# ❌ Failed to get embedding for index 396
# ❌ Failed to get embedding for index 402
# ✅ Done embedding all.

# %%
index.add(X)

# %%
print("Index type:", type(index))
print("Number of vectors:", index.ntotal)
print("Vector dimension:", index.d)
# Out:
# Index type: <class 'faiss.swigfaiss_avx2.IndexFlatL2'>
# Number of vectors: 8807
# Vector dimension: 4096

# %%
# Add to your index
faiss.write_index(index, 'index_file.idx')

# %%
index=faiss.read_index('index_file.idx')

# %%
fav_item=df.iloc[324]
res = requests.post('http://localhost:11434/api/embeddings',
    json={
        'model':'llama2',
        'prompt': fav_item['text_rep']
    }
)

# %%
embedding=np.array([res.json()['embedding']],dtype='float32')
D, I =index.search(embedding,5)

# %%
I
# Out:
# array([[ 324, 7649, 8596, 1380, 2583]], dtype=int64)

# %%
best_matches = np.array(df['text_rep'])[I.flatten()]

# %%
print(best_matches)
# Out:
# ["\n    Type:TV Show,\n    Title:44 Cats,\n    Director:nan,\n    Description:Paw-esome tales abound when singing furry friends Lampo, Milady, Pilou and Meatball band together.,\n    Genres:Kids' TV,\n    Released:2020\n    "
#  "\n    Type:TV Show,\n    Title:Ollie & Moon,\n    Director:nan,\n    Description:Two quirky cats, Ollie and Moon, and their friend Stanley the snail travel the world, solving everyday problems and learning about different cultures.,\n    Genres:Kids' TV,\n    Released:2018\n    "
#  "\n    Type:TV Show,\n    Title:Tip the Mouse,\n    Director:nan,\n    Description:In his tiny meadow village, curious little mouse Tip enjoys fun and adventure while learning about the world with his furry friends and family.,\n    Genres:Kids' TV,\n    Released:2014\n    "
#  "\n    Type:TV Show,\n    Title:Go Dog Go,\n    Director:nan,\n    Description:Handy and inventive pup Tag chases adventure with her best pal, Scooch, solving problems and helping the citizens of Pawston along the way.,\n    Genres:Kids' TV,\n    Released:2021\n    "
#  "\n    Type:TV Show,\n    Title:Masha and the Bear,\n    Director:nan,\n    Description:Lively little Masha lives near the forest, where she has many wonderful adventures with her best friend, a bear who used to be in the circus.,\n    Genres:Kids' TV,\n    Released:2019\n    "]

# %%
for match in best_matches:
    print('NEXT MOVIE')
    print(match)
    print()
# Out:
# NEXT MOVIE
#
#     Type:TV Show,
#     Title:44 Cats,
#     Director:nan,
#     Description:Paw-esome tales abound when singing furry friends Lampo, Milady, Pilou and Meatball band together.,
#     Genres:Kids' TV,
#     Released:2020
#
#
# NEXT MOVIE
#
#     Type:TV Show,
#     Title:Ollie & Moon,
#     Director:nan,
#     Description:Two quirky cats, Ollie and Moon, and their friend Stanley the snail travel the world, solving everyday problems and learning about different cultures.,
#     Genres:Kids' TV,
#     Released:2018
#
#
# NEXT MOVIE
#
#     Type:TV Show,
#     Title:Tip the Mouse,
#     Director:nan,
#     Description:In his tiny meadow village, curious little mouse Tip enjoys fun and adventure while learning about the world with his furry friends and family.,
#     Genres:Kids' TV,
#     Released:2014
#
#
# NEXT MOVIE
#
#     Type:TV Show,
#     Title:Go Dog Go,
#     Director:nan,
#     Description:Handy and inventive pup Tag chases adventure with her best pal, Scooch, solving problems and helping the citizens of Pawston along the way.,
#     Genres:Kids' TV,
#     Released:2021
#
#
# NEXT MOVIE
#
#     Type:TV Show,
#     Title:Masha and the Bear,
#     Director:nan,
#     Description:Lively little Masha lives near the forest, where she has many wonderful adventures with her best friend, a bear who used to be in the circus.,
#     Genres:Kids' TV,
#     Released:2019
